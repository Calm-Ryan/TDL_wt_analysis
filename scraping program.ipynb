# %%
import pandas as pd
from time import sleep

# %%
url = 'http://disney.showwin.asia/history/tdl?day=3&month=11&year=2017#waittime-detail'

# %%
for i in range(1, 30):
        for j in range(11,12):
            url_data = 'http://disney.showwin.asia/history/tdl?day={0}&month={1}&year=2011#waittime-detail'.format(i,j)
            dframe = pd.io.html.read_html(url_data)
            dframe[2].to_csv('wtdata_{0}_{1}_2011'.format(i,j))

# %%
pd.read_csv('wtdata_1_11_2011')
# Out:
#     Unnamed: 0     時間 \n            リバ｜鉄道 \n            カリブの海賊  \
# 0            0  08:15                   -                    -
# 1            1  08:45                   -                    -
# 2            2  09:15                   -                    5
# 3            3  09:45                  10                    5
# 4            4  10:15                  10                    5
# 5            5  10:45                  15                    5
# 6            6  11:15                  15                   20
# 7            7  11:45                  30                   20
# 8            8  12:15                  25                   20
# 9            9  12:45                  25                   25
# 10          10  13:15                  30                   25
# 11          11  13:45                  35                   25
# 12          12  14:15                  35                   25
# 13          13  14:45                  30                   25
# ...
